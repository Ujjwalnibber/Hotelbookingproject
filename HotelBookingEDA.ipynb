# %% [markdown]
# #**EDA - Hotel Booking**

# %% [markdown]
# ![photo-1517840901100-8179e982acb7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##**Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!**
# ##**This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.**
# ##**Explore and analyze the data to discover important factors that govern the bookings.**

# %% [markdown]
# #**Project Summary**
# In this EDA project we shall be exploring data to discover important factors that govern booking.We shall look at all the factors analyze them and pen down our observations.
# Exploratory Data Analysis (EDA), also known as Data Exploration, is a step in the Data Analysis Process, where a number of techniques are used to better understand the dataset being used.There are some main component of EDA,these are:
# 1. Knowing your variables
# 2. Cleaning your dataset
# 3. Studying/Understanding relationship between variables
#
#
# I have started  by first importing relevant libraries and then mounting data set. Once I have succesfully done ,then I started studying and understanding my data set like knowing shape,what each variable represents,what kind of values are present in column,what kind of datatype is preswent in columns.
#
# As a data analyst one spends 60%-70% of time cleaning data, this steps is most cruical. We shall make relevant changes to dataset in this step. I had done all the changes in dataset to copy of data(df_hotel) and not original dataset( hotel_data)  as a precautionary measure. I have sarted by first removing duplicate rows, followed by finding if there are any null values and if they are there then handling them.Once done handling null value ,I have made some changes by converting some columns into relevant data types.Further I felt some columns can be clubbed to have better understanding and some can be dropped for the same reason.Last thing done by me was handling outliers in dataset.Once I have done cleaning , I proceeded further to start EDA.
#
# The first thing I like to do when analyzing my variables is visualizing it through a correlation matrix because its the fastest way to develop a general understanding of all of my variables,followed by Univariate and bivariate analysis.Visualization is one of key factor that helps us undersatnding relationships,making conclusion or understanding trends.I have drawn all conclusions with help of different types of charts like scatter plot,bar charts , pie charts.
# In Univariate analysis indiviual column/variable has been picked up and analysis has been made like which hotels city or resort are preferred, which hotel has high cancellation rate.
# In  Bivariate analysis two columns have been  picked up and their effect on each other is seen and coclusion is drawn how they are related.Various observation like the busiest month of year,type of room preferred by guest are observed and conclusion is made how to make best use of these observation in order to have better revenue.
# Such analysis help us to find  various factors that helps  revenue to  go up, like which agent is bringing more business,which kind of hotel is preferred.
# The companies can use such conclusions and make better revenue hence solving the purpose of doing EDA.
#
# We have conclusions about various factors affecting booking like month of year,room type.To know more conclusion kindly refer last segment of the project.

# %% [markdown]
# #**GitHub Link**
#
# https://github.com/Ujjwalnibber/HotelBooking-EDA.git

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# **Mounting the drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Loading the dataset**

# %%
new_dataset = '/content/drive/MyDrive/Hotel Bookings.csv'
hotel_data = pd.read_csv(new_dataset)

# %% [markdown]
# **Let us now explore our data**

# %%
# We shall find the shape of our dataset
hotel_data.shape
# Out:
# (119390, 32)

# %% [markdown]
# Our dataset has 119390 rows and 32 columns

# %%
# top 10 rows of our dataset
hotel_data.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
#last 5 rows of our dataset
hotel_data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ###**It is important for us to know what is represented by each column, so we shall now go through descripition of each column**

# %% [markdown]
# descirption of columns
#
# 1.**hotel** : Hotel(Resort Hotel or City Hotel)
#
# 2.**is_canceled** : Value indicating if the booking was canceled (1) or not (0)
#
# 3.**lead_time** : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
#
# 4.**arrival_date_year**: Year of arrival date
#
# 5.**arrival_date_month** : Month of arrival date
#
# 6.**arrival_date_week_number** : Week number of year for arrival date
#
# 7.a**rrival_date_day_of_month** : Day of arrival date
#
# 8.**stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# 9.**stays_in_week_nights** : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# 10.**adults** : Number of adults
#
# 11.**children** : Number of children
#
# 12.**babies** : Number of babies
#
# 13.**meal** : Type of meal booked. Categories are presented in standard hospitality meal packages:
#
# 14.**country** : Country of origin.`
#
# 15.**market_segment** : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 16.**distribution_channel** : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 17.**is_repeated_guest** : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# 18.**previous_cancellations** : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19.**previous_bookings_not_canceled** : Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20.**reserved_room_type** : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# 21.**assigned_room_type** : Code for the type of room assigned to the booking.
#
# 22.**booking_changes** : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# 23.**deposit_type**: Indication on if the customer made a deposit to guarantee the booking.
#
# 24.**agent** : ID of the travel agency that made the booking
#
# 25.**company** : ID of the company/entity that made the booking or responsible for paying the booking.
#
# 26.**days_in_waiting_list** : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# 27.**customer_type** : Type of booking, assuming one of four categories
#
# 28.**adr** : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29.**required_car_parking_spaces** : Number of car parking spaces required by the customer
#
# 30.**total_of_special_requests** :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# 31.**reservation_status**: Reservation last status, assuming one of three categories
#
# Canceled – booking was canceled by the customer
#
# Check-Out – customer has checked in but already departed
#
# No-Show – customer did not check-in and did inform the hotel of the reason why
#
# 32.**reservation_status_date** : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel1,m

# %%
# We shall create a copy of our data set and store it in variable named "df_hotel",here on we shall use the copy of data to work on
df_hotel = hotel_data.copy()

# %% [markdown]
# ##**We shall now gain insights of our data by looking at information of each column**

# %%
df_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Now we know what is data type of our different columns and which columns have how many non null values

# %%
# we shall now look at our numerical columns of database and get some information about count,mean, mode of various columns
df_hotel.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ##**Let us now start cleaning our data set**

# %% [markdown]
# ###**1.Removing duplicates**

# %%
df_hotel.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
df_hotel.drop_duplicates(inplace=True)

# %%
df_hotel.shape
# Out:
# (87396, 32)

# %% [markdown]
# After dropping duplicate rows ,we have 87396 rows and 32 columns.

# %% [markdown]
# ##**2. Handling null values**

# %%
df_hotel.isna().sum().sort_values(ascending= False)[:4].reset_index().rename(columns={'index':'coulmn',0:"null Counts"})
# Out:
#      coulmn  null Counts
# 0   company        82137
# 1     agent        12193
# 2   country          452
# 3  children            4

# %% [markdown]
# These are our 4 columns with null values and their count. We shall  now handle these null values

# %%
# replacing null values with 'other'
df_hotel['country'].fillna('others', inplace = True)

# %%
#replacing nan values with 0
df_hotel[['agent']]=df_hotel[['agent']].fillna(0)

# %%
#replacing nan values with 0
df_hotel['children'].fillna(0, inplace = True)

# %%
#replacing nan values with 0
df_hotel['company'].fillna(0,inplace = True)

# %%
df_hotel.isna().sum().sort_values(ascending= False)[:4].reset_index().rename(columns={'index':'coulmn',0:"null Counts"})
# Out:
#                       coulmn  null Counts
# 0                      hotel            0
# 1                is_canceled            0
# 2         reservation_status            0
# 3  total_of_special_requests            0

# %% [markdown]
# We have been able to handle these values and now there are zero null values

# %% [markdown]
# ##**3. Converting to relevant data type**

# %%
# we shall be converting into relevant data type so that we can use these values in our calculations and have better analysis
df_hotel[['children', 'company', 'agent']] = df_hotel[['children', 'company', 'agent']].astype('int64')

# %%
df_hotel['reservation_status_date'] = pd.to_datetime(df_hotel['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# ##**4.We shall now delete those rows which are irrevelant**

# %%
#if  sum of adults and babies and kids  is zero that means there is no booking,hence we shall drop these rows
df_hotel[df_hotel['adults']+df_hotel['babies']+df_hotel['children'] == 0].shape
# Out:
# (166, 32)

# %%
df_hotel.drop(df_hotel[df_hotel['adults']+df_hotel['babies']+df_hotel['children'] == 0].index,inplace =True)

# %% [markdown]
# ##**5.Adding some relevant columns**

# %%
 # creating total people column by adding all the people in that booking
df_hotel['total_people'] = df_hotel['adults'] + df_hotel['babies'] + df_hotel['children']
# creating total stay column
df_hotel['total_stay'] = df_hotel['stays_in_weekend_nights'] + df_hotel['stays_in_week_nights']

# %%
df_hotel.shape
# Out:
# (87230, 34)

# %% [markdown]
# ##**6.Managing outliers like adr**

# %%
# checking for min and max adr values
df_hotel["adr"].min()
# Out:
# -6.38

# %%
df_hotel['adr'].max()
# Out:
# 5400.0

# %%
# adr column has maximum value as 510 and mean around 94 so 5400 is outlier.hence droppping it
df_hotel.drop(df_hotel[df_hotel['adr'] > 1000].index,inplace=True)

# %% [markdown]
# #**EDA(Exploratory Data Analysis)**
# The preliminary analysis of data to discover relationships between measures in the data and to gain an insight on the trends,patterns, annd relationships among various entities present in the data set with the help of  statistics and visulization tools is called Exploratory Data Analysis.EDA is cross classified in two different ways where each method is either graphical or non graphical.Each method is either univariate ,bivariate or multivaraiate.

# %% [markdown]
# ##**Correlation of Data**

# %% [markdown]
# **Correlation Heatmap**
#
# This plot visualize the strength of relationships between numerical variables

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df_hotel.corr(),annot=True,cmap = "Reds")
plt.title('Co-relation of the columns')
plt.show()
# Out:
# <ipython-input-30-feeefd83b1d9>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_hotel.corr(),annot=True,cmap = "Reds")

# %% [markdown]
# Observations
#
#
# 1.  We observe total stay and stay in week nights are postively correalted,hence people prefer to stay in week days too
# 2. We observe total_people and adults are highly correlated indicating most people who stay are adult
# 3. is_repeated_guest and previous_booking_not_canceled are highly and postively correalted showing people like to revisit the hotel hence increasing adr

# %% [markdown]
# #**Univariate Analysis**
#
# Uni means one and variate means variable,so in univariate analysis there is one dependable  variable.The objective of univariate analysis is to derive data,define and find insights. Univariate data can be describes through
# 1. Frequecy Distribution Table
# 2. Pie Chart
# 3. Histogram
# 4. Frequency Polygon

# %% [markdown]
# ##1.**Let us find out different types of hotels**

# %%
hotel_type =df_hotel['hotel'].value_counts()
hotel_type
# Out:
# City Hotel      53273
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %% [markdown]
# ###**Observation**
#
# We have **53273** City Hotels and **33956** Resort Hotels.
# Let us now see this graphically through pie chart(in %age) and bar chart(column representation)

# %%
plt.figure(figsize=(15,5))
df_hotel['hotel'].value_counts().plot.pie(explode=[0.02,0.02],colors=['pink','grey'],autopct='%.2f%%',fontsize=12)
plt.title('most prefered hotel')
# plt.axis('equal')
plt.show()

# %% [markdown]
# ###**Observation**
#
# So we can conclude City hotels are prefered over Resort hotels

# %%
hotel_type.plot(kind = 'bar',color = ['orange','black'],fontsize =12)
plt.title("HOTEL TYPES")
plt.ylabel("Different Hotels")
plt.xlabel("Count")
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# ##**2.Let us further explore about percentage of hotel cancellation**

# %%
# 0 is not canceled and 1 is canceled
df_hotel['is_canceled'].value_counts()
# Out:
# 0    63221
# 1    24008
# Name: is_canceled, dtype: int64

# %% [markdown]
# ###**Observation**
# **63221** hotels were not canceled
# **24008** hotels were  canceled

# %%
# %oge hotel cancellation
plt.figure(figsize=(4,6))
# plt.pie(cancelled_d, labels=['Not Cancelled', 'Cancelled'], autopct='%.1f%%', startangle=90)
df_hotel['is_canceled'].value_counts().plot.pie(explode=[0.03,0.02],colors=['pink','grey'],autopct='%.2f%%')
plt.title('percentage of cancellation & non cancellation')
plt.axis('equal')
plt.show()
# 0 is not canceled and 1 is canceled

# %% [markdown]
# ###**Observation**
#
#
# **72.48%** hotels were not canceled whereas **27.52%**were canceled

# %% [markdown]
# ##**3. Let us see various years of arrival and their count**

# %%
year_count=df_hotel['arrival_date_year'].value_counts()
year_count
year_count.plot(kind='bar',color = ['orange','black'])
# Out:
# <Axes: >

# %% [markdown]
# **Observation**
#
# As evident **2016** is the year when guests have visited most.

# %% [markdown]
# ##**4.Which hotel makes most revenue?**

# %%
most_rev = df_hotel.groupby('hotel')['adr'].count()
# Plotting the values in a pie chart
most_rev.plot.pie(autopct='%1.2f%%', figsize=(12,5),colors=("pink",'grey'))
# Setting the title
plt.title('Percentage of daily revenue by each hotel type', fontsize=20)
plt.axis('equal')
# Show the chart
plt.show()

# %% [markdown]
# ###**Observation**
#
# **61.07%** of revenue is made by **city hotel** and **38.93%** by **resort hotel**

# %% [markdown]
# ##**5. Let us see percentage of repeated guests**

# %%
plt.figure(figsize=(4,6))
df_hotel['is_repeated_guest'].value_counts().plot.pie(explode=[0.02,0.1],colors=['pink','grey'],autopct='%.2f%%')
plt.title('percentage of repeated guest and non repeated guest')
plt.axis('equal')
plt.show()
# 0 indicates not repated and 1 indicates repeated

# %% [markdown]
# ###**Observation**
#
# **96.14%** of guests are not repeated and **3.86%** are repeated

# %% [markdown]
# ##**6. Which month is the busiest?**

# %%
busiest_month_df = df_hotel['arrival_date_month'].value_counts()
busiest_month_df

busiest_month_df.plot(kind = 'bar',color=['black', 'orange',],figsize=(12,8))
plt.title('Bookings across hotels in a year')
plt.ylabel('Bookings')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ###**Observation**
#
# **August** is the busiest month followed by **July** and **May**.

# %% [markdown]
# ##**7.Preferred room type**

# %%
plt.figure(figsize=(12,6))
df_hotel['reserved_room_type'].value_counts().sort_values(ascending=False).plot.bar(width=0.8,align = 'center')
plt.title('Top  most preferred room ')
plt.xlabel('room types')
plt.ylabel('No of customers')
plt.show()

# %% [markdown]
# ###**Observation**
# A room type are most preferred over other rooms

# %% [markdown]
# ##**8. Let us now find out different customer types and their distribution**

# %%
df_hotel['customer_type'].value_counts()
# Out:
# Transient          71861
# Transient-Party    11692
# Contract            3135
# Group                541
# Name: customer_type, dtype: int64

# %%
plt.figure(figsize=(8,6))
df_hotel['customer_type'].value_counts().plot.pie(explode=[0.02,0.02,0.02,0.02],colors=['pink','grey','yellow','red'], autopct='%.2f%%')
plt.title(' percentage distribution of customer type')
plt.axis('equal')
plt.show()

# %% [markdown]
# ###**Observation**
#
# **Transient customers** have highest percentage type

# %% [markdown]
# ##**9. Percentage of people requiring car parking space**

# %%
df_hotel['required_car_parking_spaces'].value_counts()
# Out:
# 0    79923
# 1     7273
# 2       28
# 3        3
# 8        2
# Name: required_car_parking_spaces, dtype: int64

# %%
plt.figure(figsize=(12,6))
df_hotel['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.02,0.02,0.02,0.02,0.02],colors=['pink','grey','blue','black','yellow'],autopct='%.2f%%')
plt.title(' percentage distribution of customer type')
# plt.axis('equal')
plt.show()

# %% [markdown]
# ###**Observation**
#
# **91.62%** don't require parking space and **8.38%** require it

# %% [markdown]
# ##**10. The most preferred meal type**

# %%
# type of meal pre4ferred
df_hotel['meal'].value_counts()
# Out:
# BB           67906
# SC            9391
# HB            9080
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.countplot(x=df_hotel['meal'])
plt.title('Preferred meal types')
plt.show()

# %% [markdown]
# Types of meal in hotels:
#
# BB - (Bed and Breakfast)
#
# HB- (Half Board)
#
# FB- (Full Board)
#
# SC- (Self Catering)

# %% [markdown]
# ##**Observation**
# BB is most preferred meal type

# %% [markdown]
# ##**11.Which distribution channel is mostly used for booking hotel?**

# %%
# ditribution channel
df_hotel['distribution_channel'].value_counts()
# Out:
# TA/TO        69027
# Direct       12954
# Corporate     5062
# GDS            181
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_hotel['distribution_channel'].value_counts().plot.pie(explode=[0.05,0.05,0.05,0.05,0.05],colors=['pink','grey','yellow','red','black'],autopct='%.2f%%',shadow=False)
plt.title(' booking % by distribution channels')
#plt.axis('equal')
plt.show()

# %% [markdown]
# ###**Observation**
#
# TA/TO(Travel agents/Travel Operator) has highest distribution

# %% [markdown]
# ##**12. Which agent has highest booking?**

# %%
plt.figure(figsize=(8,7))
df_hotel['agent'].value_counts().head(10).plot.bar(width=0.8,align='center')
plt.title('most booking top 10 agent ')
plt.xlabel('agent')
plt.ylabel('booking count')
plt.show()

# %% [markdown]
# ###**Observation**
#
# **Agent 9** has highest booking

# %% [markdown]
# #**Bivariate Analysis**
# Bi means two and variate means variable,so here are two variables. The analysis is related to cause and the relationship between the two variable

# %% [markdown]
# ##**13. Which hotel room have highest revenue?**

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x =df_hotel['assigned_room_type'], y =df_hotel ['adr'])
plt.show()

# %% [markdown]
# ###**Observation**
#
# Hotel rooms of type **H** and **G** have highest revenue

# %% [markdown]
# ##**14. Which hotel has longer waiting time?**

# %%
waiting_time=df_hotel.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
plt.figure(figsize=(5,4))
# plot barchart
sns.barplot(x=waiting_time['hotel'],y=waiting_time['days_in_waiting_list'])
#set labels
plt.xlabel('Hotel type')
plt.ylabel('waiting time')
plt.title("Waiting time for each hotel type")
# Out:
# Text(0.5, 1.0, 'Waiting time for each hotel type')

# %% [markdown]
# ###**Observation**
#
#
# It is very evident to us that **City Hotels** have more waiting time than Resort Hotels

# %% [markdown]
# ##**15. Which market segment has highest cancellatioin rate?**

# %%
market_segment_df=df_hotel[df_hotel['is_canceled']==1]   # canceled=1
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})
#set plotsizde and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df)

# set labels
plt.xlabel('market_segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs market_segment')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs market_segment')

# %% [markdown]
# ###**Observation**
#
# we can conclude  **online TA** gas highest cancellation rates

# %% [markdown]
# ###**16. Which hotel has highest ADR**

# %%
plt.figure(figsize=(4,5))
sns.barplot(y=df_hotel['adr'],x=df_hotel['hotel'])
plt.show()

# %% [markdown]
# **City Hotel** has high adr than Resort Hotel

# %% [markdown]
# ##**17. Which month has highest revenue/adr**

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x = df_hotel['arrival_date_month'],y = df_hotel['adr'])
plt.show()

# %% [markdown]
# ###**Observation**
# **August** has got highest revenue followed by July

# %% [markdown]
# ##**18.Different stay length in different type of hotels**

# %%
plt.figure(figsize=(12,6))
twenty_day=df_hotel[df_hotel['total_stay'] < 21]
sns.countplot(x=twenty_day['total_stay'],hue=df_hotel['hotel'])
plt.show()

# %% [markdown]
# ###**Observation**
#
# We observed people stay more in City Hotel than Resort Hotels and highest average stay is between 2-3 days in city hotel.

# %% [markdown]
# ###**19. Which distribution channel contributed more to adr in order to increase the income?**

# %%
distribution_channel_df=df_hotel.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# set plot size and plot barchart
plt.figure(figsize=(10,5))
sns.barplot(x='distribution_channel', y='adr', data=distribution_channel_df, hue='hotel')
plt.title('ADR VS Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR VS Distribution channel')

# %% [markdown]
# ###**Observation**
# Corporate has added more to City Hotel adr
#
# Direct has added slightly more to City Hotel adr than Resort Hotel
#
# GDS has only contributed to City Hotel adr
#
# TA/TO also contibute more to City Hotel
#
# Undefined contributes more to Resort Hotel hence creating exception

# %% [markdown]
# ##**20.ADR VS total number of people**

# %%
plt.figure(figsize=(10,4))
df_hotel2=df_hotel[df_hotel['total_people'] < 6]

sns.boxplot(x=df_hotel2['total_people'],y=df_hotel2['adr'])

# set lables
plt.title('ADR v/s Total Number of people')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# ###**Observation**
# As number of total_people increases adr increases

# %% [markdown]
# # **SCATTER PLOT**
# A scatter plot uses dots to represent values fornteo different numeric variables.The position of each dot on yhe horizontal and vertical axis indicates values for an indiviual data point. Scatter plots are used yo observe relationships bteween variables.

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x=df_hotel['total_stay'],y=df_hotel['adr'])
plt.title('Relationship between  adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between  adr and total stay')

# %% [markdown]
# ###**Observation**
# With increase in number of stay days adr decreases

# %% [markdown]
# **CONCLUSION**
#
#
# * There are two types of Hotel : Resort and City
# * City Hotel is preferred over Resort Hotel
# * 72.48% hotels are not cancelled
# * 2016 is year with most booking
# * 61.07% of daily revenue is earned by city hotel and 38.93% by resort hotel
# * 96.14% guests are not repeated while only 3.86% guests are repeated.
# * August is the busiest month of the year
# * Approximately 75% customer are transient type.
# * BB is most preferred meal type.
# * TA/TO is highest distribution channel.
# * Agent 9 has made most booking.
# * City Hotel have higher waiting time and higher ADR.
# * As number of people increases adr increases telling both are postively related
# * Total stay on an average is less than 4 days for both the hotel types.
# * As number of days of stay increases adr decreases.
